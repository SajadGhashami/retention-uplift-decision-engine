# %% [markdown]
# # Uplift Modeling Walkthrough
#
# This notebook provides a lightweight interactive path through the project. The production-style logic remains in `src/`.

# %%
from src.data import make_synthetic_retention_experiment
from src.evaluation import experimental_ate

df = make_synthetic_retention_experiment(n=20_000, seed=42)
df.head()

# %%
df.groupby('treatment')['returned_60d'].mean()

# %%
experimental_ate(df)

# %% [markdown]
# The full modeling, validation-set policy selection, holdout evaluation, and charts are produced by running `python run_pipeline.py`.
